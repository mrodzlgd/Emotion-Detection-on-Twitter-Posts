# %%
import re
import time
import numpy as np
import pandas as pd
import requests
import sqlite3 
from sqlite3 import Error
from connect_and_create import connect_and_create_table
from progressbar import progressbar

# %% [markdown]
# ### Creating SQLite Database

# %%
sql_create_emotions_table = """ CREATE TABLE IF NOT EXISTS emotions (
                                        id integer PRIMARY KEY,
                                        text text NOT NULL,
                                        emotion text NOT NULL
                                    ); """

# %%
 database = r"C:\Users\Melissa\Documents\DS_Bootcamp\Mod_Projects\00-Capstone\Emotion-Detection-on-Twitter-Posts\data\emotion.db"

# %%
connect_and_create_table(database,sql_create_emotions_table)

# %%
conn = sqlite3.connect(database)
c = conn.cursor()

# %% [markdown]
# ## Importing TweetID with Emotion Labels

# %%
df = pd.read_csv('./data/tweetid.csv', index_col = 0 , header=0, names = ['id', 'emotion'])

# %%
df.head()
# Out:
#                    id emotion
# 0  144514632252530688   anger
# 1  147987957679263745    fear
# 2  143869765302226944     joy
# 3  148904944022470657     joy
# 4  145344771152543744    fear

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2488982 entries, 0 to 2488981
# Data columns (total 2 columns):
# id         int64
# emotion    object
# dtypes: int64(1), object(1)
# memory usage: 57.0+ MB

# %%
df.emotion.value_counts()
# Out:
# joy             706182
# sadness         616471
# anger           574170
# love            301759
# fear            135154
# thankfulness    131340
# surprise         23906
# Name: emotion, dtype: int64

# %% [markdown]
# ## Importing Text Data & Merging with Emotion Labels

# %%
filelist = ['./data/anger.csv','./data/fear.csv','./data/joy.csv','./data/sadness.csv', './data/surprise.csv','./data/thankfulness.csv','./data/love.csv']
twitter_data = pd.concat([pd.read_csv(item, usecols=[0,1,2],index_col=0 ) for item in filelist], axis=0)

# %%
twitter_data.drop_duplicates(keep = 'first', inplace = True)
twitter_data.reset_index(inplace = True)
twitter_data.drop(columns = 'index', inplace = True)

# %%
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339794 entries, 0 to 1339793
# Data columns (total 2 columns):
# id      1339794 non-null int64
# text    1339794 non-null object
# dtypes: int64(1), object(1)
# memory usage: 20.4+ MB

# %% [markdown]
# ### Merging Twitter Text with Emotion Labels

# %%
data = pd.merge(twitter_data,
         df,
         on = 'id',
         how = 'inner',
        validate = 'one_to_one')

# %%
data.head()
# Out:
#                    id                                               text  \
# 0  146975687788601344       Do not like this new twitter app #irritating
# 1  148156821444636672  @timlovejoy what's going on with us blues at t...
# 2  148543314604462080                People complain too much. #annoying
# 3  134687650601893889  The awkward moment when someone calls you out ...
# 4  144248292254031872          Chris Paul leaving the Hornets #disgusted
#
#   emotion
# 0   anger
# 1   anger
# 2   anger
# 3   anger
# 4   anger

# %%
data.shape
# Out:
# (1339794, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1339794 entries, 0 to 1339793
# Data columns (total 3 columns):
# id         1339794 non-null int64
# text       1339794 non-null object
# emotion    1339794 non-null object
# dtypes: int64(1), object(2)
# memory usage: 40.9+ MB

# %%
data.emotion.value_counts()
# Out:
# joy             386601
# sadness         330432
# anger           291480
# love            167715
# thankfulness     78228
# fear             72094
# surprise         13244
# Name: emotion, dtype: int64

# %% [markdown]
# ## Loading Data to SQLite Table

# %%
data.to_sql("emotions", conn, if_exists="append" , index = False)
conn.commit()

# %%
pd.read_sql_query("select count(*) from emotions;", conn)
# Out:
#    count(*)
# 0   1339794

# %%
pd.read_sql_query("SELECT * FROM emotions;", conn)
# Out:
#                          id  \
# 0                1865547808
# 1                1898216785
# 2                1943079793
# 3                7756449559
# 4               14400628407
# 5               20173289465
# 6               20472359733
# 7               21469384690
# 8               22984904344
# 9               24478514337
# 10              25429223198
# 11              26150577717
# 12              27366147018
# 13         3949123422130176
# 14        14102380144496641
# 15        21514120071225344
# 16        23510209976602624
# 17        24688312560132096
# 18        30272074853384192
# 19        35412977641324544
# 20        45958535552573440
# 21        46258936252334080
# 22        46926833949741056
# 23        48545572558340096
# 24        48942754704797696
# 25        49157551169880066
# 26        50745493592096768
# 27        51626813784461313
# 28        51716578303152128
# 29        54239936202805248
# ...                     ...
# 1339764  149896610254557184
# 1339765  149896613010219008
# 1339766  149896623118491648
# 1339767  149896630324297728
# 1339768  149896635068055553
# 1339769  149896642408099843
# 1339770  149896643976773632
# 1339771  149896668018520065
# 1339772  149896687811432448
# 1339773  149896702948671488
# 1339774  149896721625907201
# 1339775  149896729691557888
# 1339776  149896730274578432
# 1339777  149896750159757314
# 1339778  149896762423914497
# 1339779  149896762801393667
# 1339780  149896768295931904
# 1339781  149896770770575360
# 1339782  149896780933373953
# 1339783  149896781621235712
# 1339784  149896797047894018
# 1339785  149896797098221568
# 1339786  149896801628078081
# 1339787  149896813971910656
# 1339788  149896838210793474
# 1339789  149896840412798976
# 1339790  149896859245232128
# 1339791  149896863636660224
# 1339792  149896890077560832
# 1339793  149896892883546112
#
#                                                       text       emotion
# 0        Be gentle with yourself for we all fall down, ...          love
# 1        Weeding out negative thoughts allows inspirati...          love
# 2        There is a great divine plan to everything, ev...          love
# 3        i was asked a question.: What am i more afraid...          love
# 4                         A #Libra doesn't play with #love          love
# 5        If only everything could come with locally-gro...           joy
# 6        truth is in your mouth ~ it's tasting a lot li...          love
# 7        Just walked into a magic shop in a leafy subur...         anger
# 8        Sex is not necessarily love:: its not always :...          love
# 9        When you take things for granted the things yo...  thankfulness
# 10       You should have seen Darwin's face when he got...      surprise
# 11       Congratulations @justinbieber! My World 2.0 ha...           joy
# 12       Fall leaves, classical music, crisp breeze. #B...           joy
# 13       Nothing makes you feel quite like a kid again ...           joy
# 14       Red Lobster just denied me the right to relive...       sadness
